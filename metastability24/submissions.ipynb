# %%
import numpy as np
import pandas as pd

# %%
#data = pd.read_csv("../../../conferences/2409_metastability/metastability24_submissions.csv")
data = pd.read_csv("../../../conferences/2409_metastability/talks.csv")
data = data.assign(starttime=pd.to_datetime(data.Time, format='%H%M').dt.strftime('%H%M')).sort_values('starttime').reset_index()
data
# Out:
#     index    No  Track  Day    Time          Lastname       Firstname
# 0      33  35.0    3.0  2.0   900.0           Koseska           Aneta  \
# 1      27  28.0    3.0  3.0   900.0         Pavliotis    Grigorios A.
# 2       0   1.0    2.0  2.0   940.0        Bentivegna          Eloisa
# 3       3   4.0    1.0  2.0   940.0           Chapman            Ruth
# 4      12  13.0    1.0  3.0   940.0          Lucarini         Valerio
# 5       9  10.0    2.0  3.0   940.0                Ji          Xinrui
# 6      15  16.0    1.0  3.0  1000.0           Moroney            John
# 7      13  14.0    2.0  2.0  1000.0   Malpica-Morales         Antonio
# 8      17  18.0    2.0  3.0  1000.0            Nobili         Camilla
# 9       8   9.0    1.0  2.0  1000.0         Hernandez        Benjamin
# 10     32  34.0    3.0  1.0  1100.0               Lai      Ying-Cheng
# 11     24  25.0    1.0  3.0  1100.0            Valani           Rahil
# 12     23  24.0    1.0  2.0  1100.0             Touzo             Léo
# 13     14  15.0    2.0  2.0  1100.0            Moinat           Laure
# 14     25  26.0    2.0  3.0  1100.0           Watkins   Nicholas Wynn
# 15     20  21.0    1.0  2.0  1120.0             Römer         Raphael
# 16      7   8.0    2.0  3.0  1120.0         Del Sarto       Gianmarco
# 17      6   7.0    1.0  3.0  1120.0            Deeley            Ryan
# 18     10  11.0    2.0  2.0  1120.0          Kwasniok           Frank
# 19     30  32.0    3.0  3.0  1140.0         Serdukova         Larissa
# 20      1   2.0    3.0  1.0  1140.0            Börner            Reyk
# 21     26  27.0    3.0  2.0  1140.0        Fitzgerald           Steve
# 22     28  29.0    3.0  1.0  1400.0           Cameron           Maria
# 23      5   6.0    2.0  2.0  1400.0          Davidson       Perrin W.
# 24      2   3.0    1.0  2.0  1400.0  Brynjell-Rahkola         Mattias
# 25      4   5.0    1.0  2.0  1420.0             Daley           Kevin
# 26     11  12.0    2.0  2.0  1420.0           Lohmann        Johannes
# 27     22  23.0    2.0  2.0  1440.0             Soons           Jelle
# 28     18  19.0    1.0  2.0  1440.0            Parpas           Panos
# 29     34  36.0    3.0  1.0  1440.0        Petrovskii          Sergei
# 30     19  20.0    2.0  2.0  1500.0           Ritchie            Paul
# 31     35  37.0    1.0  2.0  1500.0          Banerjee           Ankan
# 32     29  30.0    3.0  1.0  1600.0            Dybiec      Bartłomiej
# 33     31  33.0    3.0  2.0  1600.0            Grafke          Tobias
# 34     16  17.0    3.0  1.0  1640.0           Morozov          Andrew
# 35     21  22.0    3.0  1.0  1700.0             Rossi      Kalel Luiz
# 36     36  38.0    4.0  1.0     NaN          Alqubori            Omar
# 37     37  39.0    4.0  1.0     NaN            Harteg           Jakob
# 38     38  40.0    4.0  1.0     NaN          Terpstra          Sjoerd
# 39     39  41.0    4.0  1.0     NaN              Wong        Jonathan
# 40     40  42.0    4.0  1.0     NaN          Pollacco          Joseph
# 41     41  43.0    4.0  1.0     NaN           Simpson  Callum Matthew
# 42     42  44.0    4.0  1.0     NaN             Neogi         Navonil
# 43     43  45.0    4.0  1.0     NaN            Clarke          Joseph
# 44     44  46.0    4.0  1.0     NaN       van Tegelen             Eva
# 45     45   NaN    NaN  NaN     NaN            Hobden          Bryony
# 46     46   NaN    NaN  NaN     NaN             Parry          Isobel
# 47     47   NaN    NaN  NaN     NaN            Ashwin           Peter
# 48     48   NaN    NaN  NaN     NaN          Demaerel         Thibaut
# 49     49   NaN    NaN  NaN     NaN              Nagy        Dorottya
# 50     50   NaN    NaN  NaN     NaN           Boateng           Jason
# 51     51   NaN    NaN  NaN     NaN           Agranov             Tal
# 52     52   NaN    NaN  NaN     NaN             Zhang        Jingdong
# 53     53   NaN    NaN  NaN     NaN            Singer         Michael
# 54     54   NaN    NaN  NaN     NaN            Maksym           Peter
#
#                                                 Title
# 0   Emergence of quasi-stability in biological sys...  \
# 1   phase transitions and dynamical metastability ...
# 2   The role of equation residuals in the discover...
# 3   Estimating Quasipotentials and Minimum Action ...
# 4   Response Theory Identifies Reaction Coordinate...
# 5   Chimera-inspired dynamics: When higher-order i...
# 6   Constructing Response Operators Using Koopman ...
# 7   Data-driven approach for modelling complex sys...
# 8        Scaling laws in turbulent thermal convection
# 9   Quasi-potential landscape in a bistable cloud ...
# 10  Global phase-space approach to rate-induced ti...
# 11  Tipping phenomena in inertial focusing of part...
# 12  Siegmund Duality in Physics: a bridge between ...
# 13  Applying complex networks to climate simulatio...
# 14  The Challenge of Non-Markovian Energy Balance ...
# 15                  Transition path sampling for SDEs
# 16  A non-autonomous framework for climate change ...
# 17  Dual-tipping in multiscale systems: noise intr...
# 18  Data-driven anticipation and prediction of Atl...
# 19  Lévy-noise versus Gaussian-noise-induced Trans...
# 20  Melancholia State of Metastable Ocean Currents...
# 21          Path integrals and stochastic transitions
# 22       Theory and Computation of the Quasipotential
# 23    The Rise and Fall of Carbon Cycle Instabilities
# 24  Tipping in magnetohydrodynamic channel flow th...
# 25  Mapping and control of high-dimensional, delay...
# 26  Predictability of tipping in a climate model f...
# 27  Most Likely AMOC Collapse in a Stochastic Bous...
# 28  Using Witten Laplacians to locate index-1 sadd...
# 29  Long Transients as a Possible Mechanism of Reg...
# 30  Uncertainty quantification for overshoots of t...
# 31  Efficacy and reliability of early warnings to ...
# 32                   Metastability and jump processes
# 33  Metastability and rare transitions via sharp l...
# 34  Transient metastability and apparent tipping i...
# 35  Dynamical properties and mechanisms of metasta...
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51  Generating long time scales by tuning to criti...
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#                                              Abstract
# 0   A growing body of empirical evidence suggests ...  \
# 1   we consider systems of weakly interacting diff...
# 2   Nonlinearities are pervasive in Physics, leadi...
# 3   Tipping phenomena is an active area of researc...
# 4   We consider a class of nonequilibrium systems ...
# 5   The exploration of chimera-inspired dynamics i...
# 6   Linear response theory may be used to predict ...
# 7   We introduce a data-driven methodology to appr...
# 8   Scaling laws are a useful tool in studying and...
# 9   Clouds are an integral part of our climate sys...
# 10  In ecosystems, environmental changes as a resu...
# 11  Small finite-size particles suspended in fluid...
# 12  First-passage problems are relevant in many di...
# 13  Early Warning Signals (EWS) are indicators tha...
# 14  Hasselmann’s stochastic paradigm of 1976 works...
# 15  Sampling statistical properties of noise induc...
# 16  We develop a three-timescale framework for mod...
# 17  Sudden, drastic shifts in a dynamical system’s...
# 18  A data-driven methodology for identifying, ant...
# 19  We study the impact of applying stochastic for...
# 20         Replacement talk for Kathrin Padberg-Gehle
# 21  Traditionally, stochastic processes are modell...
# 22  Many processes in nature e.g. genetic switches...
# 23  Observational records of the global carbon cyc...
# 24  In fluid systems, subcritical transition to tu...
# 25  Multistability in high-dimensional complex sys...
# 26  We study the dynamics of a global ocean model,...
# 27  The present-day Atlantic Meridional Overturnin...
# 28  We introduce a new stochastic algorithm to loc...
# 29  Ecological systems often show abrupt, signific...
# 30  Many subsystems of the Earth are at risk of un...
# 31  The quest for early warning signals (EWSs) fla...
# 32  A particle immersed in a liquid constantly int...
# 33  Metastability in complex systems manifests in ...
# 34  Traditionally, mathematical models in ecology ...
# 35  Metastability, characterized by a variability ...
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51  How does a biological system manage to produce...
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#                                           Affiliation
# 0   Cellular Computations and Learning, Max Planck...  \
# 1                             Imperial College London
# 2                                                 IBM
# 3                            University of Copenhagen
# 4                             University of Leicester
# 5   Institute of Complex Networks and Intelligent ...
# 6                             University of Leicester
# 7                             Imperial College London
# 8                                University of Surrey
# 9                                            TU Delft
# 10                           Arizona State University
# 11                               University of Oxford
# 12                                          ENS Paris
# 13                               University of Geneva
# 14  Grantham Research Institute on Climate Change ...
# 15                               University of Exeter
# 16                           Scuola Normale Superiore
# 17           Carl von Ossietzky Universität Oldenburg
# 18                               University of Exeter
# 19                            University of Leicester
# 20                              University of Reading
# 21                                University of Leeds
# 22                        University of Maryland, USA
# 23              Massachusetts Institute of Technology
# 24                     DAMTP, University of Cambridge
# 25            United States Naval Research Laboratory
# 26                           University of Copenhagen
# 27                                 Utrecht University
# 28                            Imperial College London
# 29  School of Computing and Mathematical Sciences,...
# 30                               University of Exeter
# 31  Department of Applied Mathematics, University ...
# 32  Institute of Theoretical Physics, Jagiellonian...
# 33                              University of Warwick
# 34                            University of Leicester
# 35                            University of Oldenburg
# 36                               University of Jeddah
# 37      Potsdam Institute for Climate Impact Research
# 38                                 Utrecht University
# 39                                IBM Research Europe
# 40                                IBM Research Europe
# 41                                IBM research Europe
# 42                                IBM Research Europe
# 43                               University of Exeter
# 44                              Wageningen University
# 45                               University of Exeter
# 46                               University of Exeter
# 47                               University of Exeter
# 48                                          KU Leuven
# 49                               University of Oxford
# 50                            University of Leicester
# 51                            University of Cambridge
# 52                             University of Aberdeen
# 53                                        Affiliation
# 54                            University of Leicester
#
#                                             Coauthors         Type
# 0                                                 NaN      Keynote  \
# 1                                                 NaN      Keynote
# 2                                                 NaN  Contributed
# 3                  Peter Ashwin, University of Exeter  Contributed
# 4   Niccolo' Zagli, NORDITA and Greg Pavliotis, Im...    Organiser
# 5   Xiang Li, Institute of Complex Networks and In...  Contributed
# 6                                    Valerio Lucarini  Contributed
# 7   Miguel A. Duran-Olivencia, Imperial College Lo...  Contributed
# 8                                                 NaN  Contributed
# 9                      Franziska Glassmeier, TU Delft  Contributed
# 10                                                NaN      Keynote
# 11  Brendan Harding, Victoria University of Wellin...  Contributed
# 12                Mathis Guéneau, Sorbonne Université  Contributed
# 13  Jérôme Kasparian, University of Geneva // Maur...  Contributed
# 14  Raphael Calel, Georgetown University, USA; San...  Contributed
# 15            Tobias Grafke, Reyk Börner, Ryan Deeley  Contributed
# 16          Franco Flandoli, Scuola Normale Superiore  Contributed
# 17  Peter Ashwin, University of Exeter, Ulrike Feu...  Contributed
# 18                                                NaN  Contributed
# 19  Valerio Lucarini, University of Leicester; Geo...    Organiser
# 20  Oliver Mehling, Jost v. Hardenberg and Valerio...    Organiser
# 21                                                NaN      Keynote
# 22                                      Maria Cameron      Keynote
# 23  Daniel H. Rothman, Massachusetts Institute of ...  Contributed
# 24  Yohann Duguet, LISN-CNRS, Université Paris-Sac...  Contributed
# 25  Jason M. Hindes, United States Naval Research ...  Contributed
# 26                                                NaN  Contributed
# 27  Tobias Grafke, University of Warwick; Henk A. ...  Contributed
# 28                     Tony Lelièvre, Ecole des Ponts  Contributed
# 29                                                NaN      Keynote
# 30  Kerstin Lux-Gottschalk, Eindhoven University o...  Contributed
# 31                                                NaN  Contributed
# 32                                                NaN      Keynote
# 33                                                NaN      Keynote
# 34                                                NaN  Contributed
# 35  Roberto C. Budzinski, Everton S. Medeiros, Bru...  Contributed
# 36                                                NaN       Poster
# 37                                                NaN       Poster
# 38                                                NaN       Poster
# 39                                                NaN       Poster
# 40                                                NaN       Poster
# 41                                                NaN       Poster
# 42                                                NaN       Poster
# 43                                                NaN       Poster
# 44                                                NaN       Poster
# 45                                                NaN     Attendee
# 46                                                NaN     Attendee
# 47                                                NaN    Organiser
# 48                                                NaN    Organiser
# 49                                                NaN     Attendee
# 50                                                NaN     Attendee
# 51                                                NaN       Poster
# 52                                                NaN     Attendee
# 53                                                NaN     Attendee
# 54                                                NaN     Attendee
#
#     Unnamed: 11                                   ShortAffiliation starttime
# 0           NaN  Max Planck Institute for Neurobiology of Behavior      0900
# 1           NaN                            Imperial College London      0900
# 2           NaN                                                IBM      0940
# 3           NaN                           University of Copenhagen      0940
# 4           NaN                            University of Leicester      0940
# 5           NaN                         Tongji University Shanghai      0940
# 6           NaN                            University of Leicester      1000
# 7           NaN                            Imperial College London      1000
# 8           NaN                               University of Surrey      1000
# 9           NaN                                           TU Delft      1000
# 10          NaN                           Arizona State University      1100
# 11          NaN                               University of Oxford      1100
# 12          NaN                                          ENS Paris      1100
# 13          NaN                               University of Geneva      1100
# 14          NaN  Grantham Research Institute on Climate Change ...      1100
# 15          NaN                               University of Exeter      1120
# 16          NaN                           Scuola Normale Superiore      1120
# 17          NaN           Carl von Ossietzky Universität Oldenburg      1120
# 18          NaN                               University of Exeter      1120
# 19          NaN                            University of Leicester      1140
# 20          NaN                              University of Reading      1140
# 21          NaN                                University of Leeds      1140
# 22          NaN                             University of Maryland      1400
# 23          NaN              Massachusetts Institute of Technology      1400
# 24          NaN                            University of Cambridge      1400
# 25          NaN            United States Naval Research Laboratory      1420
# 26          NaN                           University of Copenhagen      1420
# 27          NaN                                 Utrecht University      1440
# 28          NaN                            Imperial College London      1440
# 29          NaN                            University of Leicester      1440
# 30          NaN                               University of Exeter      1500
# 31          NaN                                University of Leeds      1500
# 32          NaN                            Jagiellonian University      1600
# 33          NaN                              University of Warwick      1600
# 34          NaN                            University of Leicester      1640
# 35          NaN                            University of Oldenburg      1700
# 36          NaN                               University of Jeddah       NaN
# 37          NaN      Potsdam Institute for Climate Impact Research       NaN
# 38          NaN                                 Utrecht University       NaN
# 39          NaN                                IBM Research Europe       NaN
# 40          NaN                                IBM Research Europe       NaN
# 41          NaN                                IBM research Europe       NaN
# 42          NaN                                IBM Research Europe       NaN
# 43          NaN                               University of Exeter       NaN
# 44          NaN                              Wageningen University       NaN
# 45          NaN                               University of Exeter       NaN
# 46          NaN                               University of Exeter       NaN
# 47          NaN                               University of Exeter       NaN
# 48          NaN                                          KU Leuven       NaN
# 49          NaN                               University of Oxford       NaN
# 50          NaN                            University of Leicester       NaN
# 51          NaN                            University of Cambridge       NaN
# 52          NaN                             University of Aberdeen       NaN
# 53          NaN                                        Affiliation       NaN
# 54          NaN                            University of Leicester       NaN

# %%
data.columns.values.tolist()
# Out:
# ['index',
#  'No',
#  'Track',
#  'Day',
#  'Time',
#  'Lastname',
#  'Firstname',
#  'Title',
#  'Abstract',
#  'Affiliation',
#  'Coauthors',
#  'Type',
#  'starttime']

# %%
"""
for i in range(len(data)):
    if data["Type"][i] == 'Contributed talk (12 min + 5 min questions)':
        print("<h3>{}</h3>".format(str(data["Title"][i])))
        if type(data["Coauthors"][i]) == float:
            print("<p><b>{}</b>, {}</p>".format(
            str(data["Name"][i]), str(data["Affiliation"][i])
        ))
        else:
            print("<p><b>{}</b>, {}<br>with {}</p>".format(
            str(data["Name"][i]), str(data["Affiliation"][i]), str(data["Coauthors"][i])
        ))
        print("<p>{}</p>".format(str(data["Abstract"][i])))
        print("")
"""
# Out:
# '\nfor i in range(len(data)):\n    if data["Type"][i] == \'Contributed talk (12 min + 5 min questions)\':\n        print("<h3>{}</h3>".format(str(data["Title"][i])))\n        if type(data["Coauthors"][i]) == float:\n            print("<p><b>{}</b>, {}</p>".format(\n            str(data["Name"][i]), str(data["Affiliation"][i])\n        ))\n        else:\n            print("<p><b>{}</b>, {}<br>with {}</p>".format(\n            str(data["Name"][i]), str(data["Affiliation"][i]), str(data["Coauthors"][i])\n        ))\n        print("<p>{}</p>".format(str(data["Abstract"][i])))\n        print("")\n'

# %%
def endtime(data, i):
    if data["Type"][i] == 'Keynote':
        return (pd.to_datetime(data.Time[i], format='%H%M') + pd.Timedelta(minutes=40)).strftime('%H%M')
    else:
        return (pd.to_datetime(data.Time[i], format='%H%M') + pd.Timedelta(minutes=20)).strftime('%H%M')
    
days = ['Tuesday', 'Wednesday', 'Thursday']

# %%
for i in range(len(data)):
    for j in [1]:
        if data["Type"][i] == 'Keynote' and data['Day'][i]==j:
            print("<h4>{}</h4>".format(str(data["Title"][i])))
            if type(data["Coauthors"][i]) == float:
                print("<p><b>{} {}</b>, {}<br><i>{}, {}-{}, Room {}</i></p>".format(
                str(data['Firstname'][i]), str(data["Lastname"][i]), str(data["Affiliation"][i]),
                days[data['Day'][i]-1], pd.to_datetime(data['Time'][i], format='%H%M').strftime(format='%H:%M'), pd.to_datetime(endtime(data, i), format='%H%M').strftime(format='%H:%M'), data['Track'][i]
            ))
            else:
                print("<p><b>{} {}</b>, {}<br>with {}<br><i>{}, {}-{}, Room {}</i></p>".format(
                str(data['Firstname'][i]), str(data["Lastname"][i]), str(data["Affiliation"][i]), str(data["Coauthors"][i]),
                days[data['Day'][i]-1], pd.to_datetime(data['Time'][i], format='%H%M').strftime(format='%H:%M'), pd.to_datetime(endtime(data, i), format='%H%M').strftime(format='%H:%M'), data['Track'][i]
            ))
            print("<p>{}</p>".format(str(data["Abstract"][i])))
            print("")
# Out:
# <h4>Global phase-space approach to rate-induced tipping in complex biological networks</h4>
# <p><b>Ying-Cheng Lai</b>, Arizona State University<br><i>Tuesday, 11:00-11:40, Room 3</i></p>
# <p>In ecosystems, environmental changes as a result of natural and human processes can cause some key parameters to change with time. Depending on how fast such a parameter changes, a tipping event can occur. Existing works on rate-induced tipping, or R-tipping, provided mathematical insights into this phenomenon in low-dimensional systems from a local dynamical point of view, revealing, e.g., the existence of a critical rate for some specific initial condition above which tipping will occur. Motivated by the observation that ecosystems are dynamic, most likely transient, and constantly driven away from some equilibrium state, we develop a global phase-space approach to R-tipping. In particular, we introduce the notion of the probability of R-tipping defined for initial conditions in the phase space. Using real-world, complex high-dimensional mutualistic networks as a paradigm, we discover a scaling law between this probability and the rate of parameter change, and provide a geometric theory to explain the scaling. Our analysis elucidates the meaning of the critical rate and its dependence on initial conditions. The phase-space approach offers a comprehensive physical framework to understand R-tipping.
#
# This is a joint work with Dr. Shirin Panahi from Arizona State University, Prof. Younghae Do from Kyungpook National University in South Korea, and Prof. Alan Hastings from UC Davis.
#
# References on which the talk is based:
#
# 1.	S. Panahi, Y.-H. Do, A. Hastings, and Y.-C. Lai, “Rate-induced tipping in high-dimensional complex ecological networks,” PNAS 120, e2308820120, 1-9 (December 2023).
# 2.	J.-J. Jiang, Z.-G. Huang, T. P. Seager, W. Lin, C. Grebogi, A. Hastings, and Y.-C. Lai, “Predicting tip-ping points in mutualistic networks through dimension reduction,” PNAS 115, E639-E647 (2018).
# 3.	J.-J. Jiang, A. Hastings, and Y.-C. Lai, “Harnessing tipping points in complex ecological networks,” Journal of the Royal Society Interface 16, 20190345 (2019).</p>
#
# <h4>Metastability and almost-invariant sets (cancelled)</h4>
# <p><b>Kathrin Padberg-Gehle</b>, Leuphana University Lüneburg<br><i>Tuesday, 11:40-12:20, Room 3</i></p>
# <p>Metastability and almost-invariant sets are key concepts in the study of dynamical systems as they determine the long-term behavior of complex systems. An almost-invariant set is a subset of state space characterized by the property that trajectories starting in it have a high probability of remaining in the set over a significant time duration. We will discuss numerical methods for the identification and characterization of almost-invariant sets and also address data-based and nonautonomous extensions. All approaches are demonstrated in a number of example systems, including turbulent Rayleigh-Bénard convection.</p>
#
# <h4>Melancholia State of Metastable Ocean Currents and its Role for Critical Transitions</h4>
# <p><b>Reyk Börner</b>, University of Reading<br>with Oliver Mehling, Jost v. Hardenberg and Valerio Lucarini<br><i>Tuesday, 11:40-12:20, Room 3</i></p>
# <p>Replacement talk for Kathrin Padberg-Gehle</p>
#
# <h4>Theory and Computation of the Quasipotential</h4>
# <p><b>Maria Cameron</b>, University of Maryland, USA<br>with Maria Cameron<br><i>Tuesday, 14:00-14:40, Room 3</i></p>
# <p>Many processes in nature e.g. genetic switches, ecological systems, and nonlinear oscillators with periodic forcing can be modeled using stochastic differential equations (SDEs) with small noise. For gradient SDEs, the invariant probability measure and the most probable escape paths from the attractors can be expressed in terms of their potential functions. For nongradient SDEs, the counterpart of the potential function is the quasipotential, a key function in the large deviations theory (Freidlin and Wentzell, 1970s — 2010s). The quasipotential is a function defined on the phase space as the solution to a certain optimal control problem. It allows us to obtain asymptotic estimates for the invariant measure in the small noise limit, find the most probable escape paths, and facilitate the visualization of the stochastic dynamics. I will give an overview of the theory of the quasipotential and discuss two approaches to computing it in whole regions of the phase space. The first approach is based on a greedy algorithm for solving a certain optimal control problem on the mesh in the phase space. The second approach directly computes the Lagrangian manifold in the lifted space and then projects the quasipotential level sets to the phase space.</p>
#
# <h4>Long Transients as a Possible Mechanism of Regime Shifts and Metastable Dynamics in Ecosystems</h4>
# <p><b>Sergei Petrovskii</b>, School of Computing and Mathematical Sciences, University of Leicester<br><i>Tuesday, 14:40-15:20, Room 3</i></p>
# <p>Ecological systems often show abrupt, significant changes - regime shifts - in response to apparently small, gradual changes in environmental conditions. Moreover, sometimes a regime shift happens without any clear reasons at all. Growing empirical evidence eventually led to a mathematical concept of tipping points [1]. In particular, B-tipping links an abrupt change to a bifurcation, e.g. to a saddle-node bifurcation resulting in a disappearance of a stable steady state. A few different types of tipping mechanisms have been suggested such as N-tipping (transitions in a multi-well potential due to the effect of noise), R-tipping (transitions due to a high rate of change) and P-tipping (extreme sensitivity during certain phases of system’s dynamics, cf. [2]). In my talk, I will discuss an alternative, different mechanism that can result in metastable dynamics: long transients [3]. During long transient dynamics, the system can mimic a possible asymptotical regime (e.g., steady state, limit cycle, or chaos) over an indefinitely long yet finite period of time before undergoing a fast transition to a different regime. There is a variety of mathematical structures that can lead to long transient dynamics, such as ‘crawlbys’, ghost attractors, slow-fast timescales, etc. [3,4]. I will emphasize the relation between long transients and metastability and argue that such “LT-tipping” is a plausible alternative to other types of tipping, in particular as it does not necessarily require presumptions needed for other types of tipping to occur.
# References
# [1] Ashwin P, Wieczorek S, Vitolo R, Cox P. 2012. Tipping points in open systems: bifurcation, noise-induced and rate-dependent examples in the climate system. Phil. Trans. R. Soc. A 370, 1166-1184.
# [2] Alkhayuon H, Tyson RC, Wieczorek S. 2021. Phase tipping: how cyclic ecosystems respond to contemporary climate. Proc. R. Soc. A 477, 20210059.
# [3] Hastings A, Abbott KC, Cuddington K, et al. 2018. Transient phenomena in ecology. Science 361, eaat6412.
# [4] Morozov A, Abbott KC, Cuddington K, et al. 2020. Long transients in ecology: Theory and applications. Physics of Life Reviews 32, 1-40.</p>
#
# <h4>Metastability and jump processes</h4>
# <p><b>Bartłomiej Dybiec</b>, Institute of Theoretical Physics, Jagiellonian University<br><i>Tuesday, 16:00-16:40, Room 3</i></p>
# <p>A particle immersed in a liquid constantly interacts with other particles. Due to the enormous number of collisions, these interactions cannot be described exactly. An effective approximate description is provided by noise. Noise is a stochastic process that is used to describe complicated or not fully known interactions. According to central limit theorems, the sum of many independent identically distributed random variables tends to the Gaussian distribution (if components are characterized by finite variance) or to the α-stable density (diverging variance of components). Consequently, the Lévy noise and its special case—the Gaussian white noise (GWN)—are frequently used in the description of noise driven systems in the out-of-equilibrium and equilibrium regimes, respectively. Both of them share numerous similarities, however they significantly and inherently differs. α-stable noises (with α<2) inevitably lead to occurence of long jumps. Increasing number of observations demonstrates a plethora of situations in which non-Gaussian heavy tailed fluctuations are recorded. This indicates the need to in clude heavy-tailed fluctuations in the description of dynamical systems especially in out-of-equilibrium realms. The possibility of anomalously long jumps, drastically changes the properties of stochastic dynamical systems compared to their Gaussian noise driven counterparts. It is the long jumps that lead to bimodal non-equilibrium stationary states in single-well, super-harmonic, potential wells. Exploration of different scenarios for restricting or eliminating long jumps, allows for a better understanding of how long jumps determine the properties of stationary states and how they affect their modality. This provides a deeper understanding of the role of non-Gaussian long jumps and the mechanisms responsible for emergence of multimodal stationary states. [1] P. Pogorzelec and B. Dybiec, Resetting induced multimodality, Chaos 33, 063105 (2023). [2] P. Pogorzelec and B. Dybiec, Role of long jumps in Lévy noise-induced multimodality, Chaos 34, 063136 (2024)</p>

# %%
def print_schedule(data, day):
    print(r'<h3 id="schedule-heading">{}, {} September</h3>'.format(days[day-1], day+2))
    print(r'<div class="schedule" aria-labelledby="schedule-heading">')
    print(r'<span class="track-slot" aria-hidden="true" style="grid-column: track-1; grid-row: tracks;">Room 1</span>')
    print(r'<span class="track-slot" aria-hidden="true" style="grid-column: track-2; grid-row: tracks;">Room 2</span>')
    print(r'<h2 class="time-slot" style="grid-row: time-0900;">9:00am</h2>')
    print("")
    for i in range(len(data)):
        if data.Day[i] == day:
            day = data['Day'][i]
            if data['Track'][i] == 3:
                track = "track-1-start / track-2-end"
            else:
                track = "track-{}".format(data['Track'][i])
            start = data['Time'][i]
            end = endtime(data, i)
            print(r'<div class="session session-{} track-{}" style="grid-column: {}; grid-row: time-{} / time-{};">'.format(
                day, data['Track'][i], track, start, end))
            print(r'<h3 class="session-title"><a href="#">{}</a></h3>'.format(
                data.Title[i]
            ))
            print(r'<span class="session-presenter">{} {}</span>'.format(
                data.Firstname[i], data.Lastname[i]
            ))
            print(r'<span class="session-time">{} - {}</span>'.format(
                pd.to_datetime(start, format='%H%M').strftime(format='%H:%M'), pd.to_datetime(end, format='%H%M').strftime(format='%H:%M')
            ))
            print(r'<span class="session-track">Room {}</span>'.format(
                2-data.Track[i]%2
            ))
            print("</div>")
    print("</div>")
    print("")

print_schedule(data, 3)
#print_schedule(data, 2)
#print_schedule(data, 3)
# Out:
# <h3 id="schedule-heading">Thursday, 5 September</h3>
# <div class="schedule" aria-labelledby="schedule-heading">
# <span class="track-slot" aria-hidden="true" style="grid-column: track-1; grid-row: tracks;">Room 1</span>
# <span class="track-slot" aria-hidden="true" style="grid-column: track-2; grid-row: tracks;">Room 2</span>
# <h2 class="time-slot" style="grid-row: time-0900;">9:00am</h2>
#
# <div class="session session-3 track-3" style="grid-column: track-1-start / track-2-end; grid-row: time-900 / time-0940;">
# <h3 class="session-title"><a href="#">phase transitions and dynamical metastability for stochastic interacting particle systems</a></h3>
# <span class="session-presenter">Grigorios A. Pavliotis</span>
# <span class="session-time">09:00 - 09:40</span>
# <span class="session-track">Room 1</span>
# </div>
# <div class="session session-3 track-1" style="grid-column: track-1; grid-row: time-940 / time-1000;">
# <h3 class="session-title"><a href="#">Response Theory Identifies Reaction Coordinates and Explains Critical Phenomena in Noisy Interacting Systems</a></h3>
# <span class="session-presenter">Valerio Lucarini</span>
# <span class="session-time">09:40 - 10:00</span>
# <span class="session-track">Room 1</span>
# </div>
# <div class="session session-3 track-2" style="grid-column: track-2; grid-row: time-940 / time-1000;">
# <h3 class="session-title"><a href="#">Chimera-inspired dynamics: When higher-order interactions are expressed differently</a></h3>
# <span class="session-presenter">Xinrui Ji</span>
# <span class="session-time">09:40 - 10:00</span>
# <span class="session-track">Room 2</span>
# </div>
# <div class="session session-3 track-1" style="grid-column: track-1; grid-row: time-1000 / time-1020;">
# <h3 class="session-title"><a href="#">Constructing Response Operators Using Koopman Formalism</a></h3>
# <span class="session-presenter">John Moroney</span>
# <span class="session-time">10:00 - 10:20</span>
# <span class="session-track">Room 1</span>
# </div>
# <div class="session session-3 track-2" style="grid-column: track-2; grid-row: time-1000 / time-1020;">
# <h3 class="session-title"><a href="#">Scaling laws in turbulent thermal convection</a></h3>
# <span class="session-presenter">Camilla Nobili</span>
# <span class="session-time">10:00 - 10:20</span>
# <span class="session-track">Room 2</span>
# </div>
# <div class="session session-3 track-2" style="grid-column: track-2; grid-row: time-1100 / time-1120;">
# <h3 class="session-title"><a href="#">The Challenge of Non-Markovian Energy Balance Models in Climate</a></h3>
# <span class="session-presenter">Nicholas Wynn Watkins</span>
# <span class="session-time">11:00 - 11:20</span>
# <span class="session-track">Room 2</span>
# </div>
# <div class="session session-3 track-1" style="grid-column: track-1; grid-row: time-1100 / time-1120;">
# <h3 class="session-title"><a href="#">Tipping phenomena in inertial focusing of particles</a></h3>
# <span class="session-presenter">Rahil Valani</span>
# <span class="session-time">11:00 - 11:20</span>
# <span class="session-track">Room 1</span>
# </div>
# <div class="session session-3 track-1" style="grid-column: track-1; grid-row: time-1120 / time-1140;">
# <h3 class="session-title"><a href="#">Dual-tipping in multiscale systems: noise introduces uncertainty to rate-dependent transition scenarios</a></h3>
# <span class="session-presenter">Ryan Deeley</span>
# <span class="session-time">11:20 - 11:40</span>
# <span class="session-track">Room 1</span>
# </div>
# <div class="session session-3 track-2" style="grid-column: track-2; grid-row: time-1120 / time-1140;">
# <h3 class="session-title"><a href="#">A non-autonomous framework for climate change and extreme weather events increase in a stochastic energy balance model</a></h3>
# <span class="session-presenter">Gianmarco Del Sarto</span>
# <span class="session-time">11:20 - 11:40</span>
# <span class="session-track">Room 2</span>
# </div>
# <div class="session session-3 track-3" style="grid-column: track-1-start / track-2-end; grid-row: time-1140 / time-1220;">
# <h3 class="session-title"><a href="#">Lévy-noise versus Gaussian-noise-induced Transitions in the Ghil-Sellers Energy Balance Model</a></h3>
# <span class="session-presenter">Larissa Serdukova</span>
# <span class="session-time">11:40 - 12:20</span>
# <span class="session-track">Room 1</span>
# </div>
# </div>

# %%
len(data)
# Out:
# 36

# %%
min(1,2)
# Out:
# 1

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print_schedule(data)
#
# Cell In[21], line 3, in print_schedule(data)
#       1 def print_schedule(data):
#       2     for i, d in enumerate(data):
# ----> 3         day = d['Day']
#       4         track = d['Track']
#       5         print(r'<div class="session session-{} track-{}" style="grid-column: track-{}; grid-row: time-0800 / time-0900;">'.format(day, track, track))
#
# TypeError: string indices must be integers, not 'str'

# %%
endtime(data, 0)
# Out:
# '1000'

# %%
80%60
# Out:
# 20

# %%
(pd.to_datetime(data.Time[0], format='%H%M') + pd.Timedelta(minutes=40)).strftime('%H%M')
# Out:
# '1020'

# %%
print(data['Abstract'][1])
# Out:
# A growing body of empirical evidence suggests that neuronal and biochemical networks are often
# characterized by long transients which are quasi-stable, with fast switching between them. The
# duration of the quasi-stable patterns is much longer than one would expect from the characteristic
# elementary processes of the system, whereas the switching is triggered by external signals or
# system-autonomously, and occurs on a timescale much shorter than the one of the preceding
# dynamical pattern. Generalizing the concept of ghost states, we provide a theoretical framework
# that accounts for emergence of transiently stable phase-space flows generated by ghost scaffolds.
# We demonstrate that ghost-based phase space objects such as ghost channels and cycles account
# for emergence of advanced information processing capabilities, including on-the-fly signal
# classification, temporal integration and context-dependent responses.

# %%
for i in range(len(data)):
    if data.Type[i] == 'Keynote':
        print(data.Lastname[i], ", ", data.Title[i])
# Out:
# Pavliotis ,  phase transitions and dynamical metastability for stochastic interacting particle systems
# Koseska ,  Emergence of quasi-stability in biological systems
# Lai ,  Global phase-space approach to rate-induced tipping in complex biological networks
# Fitzgerald ,  Path integrals and stochastic transitions
# Serdukova ,  Lévy-noise versus Gaussian-noise-induced Transitions in the Ghil-Sellers Energy Balance Model
# Padberg-Gehle ,  Metastability and almost-invariant sets
# Cameron ,  Theory and Computation of the Quasipotential
# Petrovskii ,  Long Transients as a Possible Mechanism of Regime Shifts and Metastable Dynamics in Ecosystems
# Dybiec ,  Metastability and jump processes
# Grafke ,  Metastability and rare transitions via sharp large deviation estimates

# %%
def role(type):
    if type == 'Keynote':
        return 'Keynote speaker'
    elif type == 'Contributed':
        return 'Speaker'
    elif type == 'Organiser':
        return 'Organiser'
    elif type == 'Poster':
        return 'Presenter'
    else:
        return 'Attendee'

for i in range(50,55):
    print(
        "\item \\businesscard{}{}{}{}".format(
            "{"+data['Firstname'][i]+"}",
            "{"+data['Lastname'][i]+"}",
            "{"+data['ShortAffiliation'][i]+"}",
            "{"+role(data['Type'][i])+"}"
        )
    )
# Out:
# \item \businesscard{Jason}{Boateng}{University of Leicester}{Attendee}
# \item \businesscard{Tal}{Agranov}{University of Cambridge}{Presenter}
# \item \businesscard{Jingdong}{Zhang}{University of Aberdeen}{Attendee}
# \item \businesscard{Michael}{Singer}{Affiliation}{Attendee}
# \item \businesscard{Peter}{Maksym}{University of Leicester}{Attendee}
